# %%
print("Hola desde Jupyter")
# Out:
# Hola desde Jupyter

# %%
import pandas as pd, numpy as np, matplotlib, seaborn, sklearn
print("✅ Librerías cargadas correctamente")
# Out:
# ✅ Librerías cargadas correctamente

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\laura\OneDrive\CompartidoCasa\Master BIG DATA\13MBID\AG1\cd13MBID-AG1-LauraTrallero\.venv\Scripts\python.exe

# %%
import os
os.listdir('../data')
# Out:
# ['processed', 'raw', 'README.md']
